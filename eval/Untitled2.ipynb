# %%
import PyPDF2

# %%
# !wget "https://www.ipcc.ch/report/ar6/syr/downloads/report/IPCC_AR6_SYR_LongerReport.pdf" -O "ipcc_report.pdf"
# Out:
# --2024-08-21 13:12:30--  https://www.ipcc.ch/report/ar6/syr/downloads/report/IPCC_AR6_SYR_LongerReport.pdf
# Resolving www.ipcc.ch (www.ipcc.ch)... 2606:4700:8de4:eefd:38fd:71:6814:fe03, 104.20.255.3, 104.20.254.3, ...
# Connecting to www.ipcc.ch (www.ipcc.ch)|2606:4700:8de4:eefd:38fd:71:6814:fe03|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5218936 (5.0M) [application/pdf]
# Saving to: ‘ipcc_report.pdf’
#
# ipcc_report.pdf     100%[===================>]   4.98M   240KB/s    in 16s
#
# 2024-08-21 13:12:50 (328 KB/s) - ‘ipcc_report.pdf’ saved [5218936/5218936]

# %%
text=""
with open("./ipcc_report.pdf", 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    num_pages = len(reader.pages)
    for page_num in range(num_pages):
        text += reader.pages[page_num].extract_text()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1024, chunk_overlap=200, separators=[".", "\n"], length_function=len)

# %%
chunks = text_splitter.create_documents([text])

# %%
from langchain_chroma import Chroma
from langchain_google_vertexai import VertexAI
from langchain_community.embeddings import VertexAIEmbeddings
from langchain_google_vertexai import VertexAI
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain.chains import create_history_aware_retriever
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.prompts import (
    PromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
    ChatPromptTemplate,
)

# %%
Chroma.from_documents(documents=chunks, embedding=VertexAIEmbeddings(),persist_directory="./db")
# Out:
# /home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `VertexAIEmbeddings` was deprecated in LangChain 0.0.12 and will be removed in 0.3.0. An updated version of the class exists in the langchain-google-vertexai package and should be used instead. To use it run `pip install -U langchain-google-vertexai` and import as `from langchain_google_vertexai import VertexAIEmbeddings`.
#   warn_deprecated(
# Model_name will become a required arg for VertexAIEmbeddings starting from Feb-01-2024. Currently the default is set to textembedding-gecko@001

# %%
retriever = Chroma(persist_directory="./db", embedding_function=VertexAIEmbeddings()).as_retriever()
# Out:
# Model_name will become a required arg for VertexAIEmbeddings starting from Feb-01-2024. Currently the default is set to textembedding-gecko@001

# %%
contextualize_q_system_prompt = """Given a chat history and the latest user question \
which might reference context in the chat history, formulate a standalone question \
which can be understood without the chat history. Do NOT answer the question, \
just reformulate it if needed and otherwise return it as is."""

contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", contextualize_q_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)

qa_system_prompt = """You are an assistant for question-answering tasks. \
Use the following pieces of retrieved context to answer the question. \
If you don't know the answer, just say that you don't know. \
Use three sentences maximum and keep the answer concise.\

{context}"""

qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", qa_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)

# %%
safety_settings: [
    {
      "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
      "threshold": "BLOCK_NONE"
    },
    {
      "category": "HARM_CATEGORY_HATE_SPEECH",
      "threshold": "BLOCK_LOW_AND_ABOVE"
    },
    {
      "category": "HARM_CATEGORY_HARASSMENT",
      "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    },
    {
      "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
      "threshold": "BLOCK_ONLY_HIGH"
    }
  ]

# %%
session_id = "xyz300"

CHAT_MODEL=VertexAI(model_name="gemini-pro")


history_aware_retriever = create_history_aware_retriever(
    CHAT_MODEL, retriever, contextualize_q_prompt
)

question_answer_chain = create_stuff_documents_chain(CHAT_MODEL, qa_prompt)

rag_chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

store = {}
store[session_id] = ChatMessageHistory()

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]


conversational_rag_chain = RunnableWithMessageHistory(
    rag_chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="chat_history",
    output_messages_key="answer",
)

# %%
conversational_rag_chain.invoke(
    {"input": "What was the global surface temperature"},
    config={
        "configurable": {"session_id": session_id}
    })["answer"]
# Out:
# 'The global surface temperature has increased by 1.1°C since the pre-industrial period (1850-1900). This warming is primarily due to human activities, such as the burning of fossil fuels. The most recent decade (2011-2020) was around 1.1°C warmer than 1850-1900. This is the highest average global surface temperature for at least 125,000 years. '

# %%
from giskard.rag import KnowledgeBase, generate_testset, QATestset
import pandas as pd

# %%
import os
import giskard

import google.generativeai as genai

from giskard.llm.client.gemini import GeminiClient

genai.configure(api_key="api key")

giskard.llm.set_default_client(GeminiClient(model="gemini-pro"))

# %%
GeminiClient?
# Out:
# Init signature: GeminiClient(model: str = 'gemini-pro', _client=None)
# Docstring:
# Helper class that provides a standard way to create an ABC using
# inheritance.
# File:           ~/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py
# Type:           ABCMeta
# Subclasses:

# %%
knowledge_base_df = pd.DataFrame([node.page_content for node in chunks], columns=["text"])

# %%
knowledge_base = KnowledgeBase(knowledge_base_df,embedding_model=VertexAIEmbeddings())
# Out:
# 2024-08-21 14:05:08,303 pid:182292 MainThread langchain_community.embeddings.vertexai WARNING  Model_name will become a required arg for VertexAIEmbeddings starting from Feb-01-2024. Currently the default is set to textembedding-gecko@001

# %%
testset = generate_testset(knowledge_base,
                           num_questions=120,
                           agent_description="A chatbot answering questions about the IPCC report")
# Out:
# 2024-08-21 14:05:12,393 pid:182292 MainThread giskard.rag  INFO     Finding topics in the knowledge base.
# 2024-08-21 14:05:48,315 pid:182292 MainThread giskard.rag  INFO     Found 9 topics in the knowledge base.
# Generating questions:   0%|          | 0/120 [00:00<?, ?it/s]
# 2024-08-21 14:05:48,646 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:48,647 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:48,953 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:48,954 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:49,227 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:49,228 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:49,551 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:49,553 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:49,862 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:49,864 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:50,181 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:50,183 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:50,590 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:50,592 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:50,999 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:50,999 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:51,303 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:51,303 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:51,614 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:51,617 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:52,023 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:52,024 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:52,350 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:52,351 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:52,741 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:52,743 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:53,151 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:53,151 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:53,561 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:53,561 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:53,860 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:53,860 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 Please use a valid role: user, model.
# 2024-08-21 14:05:54,173 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 400 Please use a valid role: user, model.. Skipping.
# 2024-08-21 14:05:54,174 pid:182292 MainThread giskard.rag  ERROR    400 Please use a valid role: user, model.
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
# ...
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
# 2024-08-21 14:06:28,991 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 429 Resource has been exhausted (e.g. check quota).. Skipping.
# 2024-08-21 14:06:28,993 pid:182292 MainThread giskard.rag  ERROR    429 Resource has been exhausted (e.g. check quota).
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
# 2024-08-21 14:06:29,269 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 429 Resource has been exhausted (e.g. check quota).. Skipping.
# 2024-08-21 14:06:29,271 pid:182292 MainThread giskard.rag  ERROR    429 Resource has been exhausted (e.g. check quota).
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
# 2024-08-21 14:06:29,606 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 429 Resource has been exhausted (e.g. check quota).. Skipping.
# 2024-08-21 14:06:29,608 pid:182292 MainThread giskard.rag  ERROR    429 Resource has been exhausted (e.g. check quota).
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
# 2024-08-21 14:06:29,882 pid:182292 MainThread giskard.rag  ERROR    Encountered error in question generation: 429 Resource has been exhausted (e.g. check quota).. Skipping.
# 2024-08-21 14:06:29,882 pid:182292 MainThread giskard.rag  ERROR    429 Resource has been exhausted (e.g. check quota).
# Traceback (most recent call last):
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 57, in generate_questions
#     yield self.generate_single_question(knowledge_base, *args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/simple_questions.py", line 96, in generate_single_question
#     generated_qa = self._llm_complete(messages=messages)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/question_generators/base.py", line 42, in _llm_complete
#     out = self._llm_client.complete(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/llm/client/gemini.py", line 74, in complete
#     completion = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/generativeai/generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py", line 827, in generate_content
#     response = rpc(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py", line 144, in retry_target
#     result = target()
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#   File "/home/debian/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_182292/2948970355.py in ?()
# ----> 1 testset = generate_testset(knowledge_base,
#       2                            num_questions=120,
#       3                            agent_description="A chatbot answering questions about the IPCC report")
#
# ~/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/testset_generation.py in ?(knowledge_base, num_questions, question_generators, language, agent_description)
#      97             "question_generators": [qg.__class__.__name__ for qg in question_generators],
#      98             "knowledge_base_size": len(knowledge_base._documents),
#      99         },
#     100     )
# --> 101     return QATestset(questions)
#
# ~/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/testset.py in ?(self, question)
#      43     def __init__(self, question: Sequence[QuestionSample]):
#      44         self._questions = question
# ---> 45         self._dataframe = pd.DataFrame.from_records([question.to_dict() for question in self._questions]).set_index(
#      46             "id"
#      47         )
#
# ~/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['id'] are in the columns"

# %%
testset = QATestset.load("ipcc_testset.jsonl")

# %%
testset.to_pandas().head(5)
# Out:
#                                                                                question  \
# id
# 450623f7-e644-4bfa-88d5-90f31dd15d99  What are the consequences of global warming ex...
# 79f98d3d-766b-4cbf-800f-03e87966e3e5  What is the projected decline in coral reefs w...
# 1ee224a2-62af-4877-b172-baec006512e6  What is the expected uncertainty range in the ...
# 16264bd2-510a-4368-a9d6-0a5fef7feb65  What is the effect of increasing cumulative ne...
# c31c6857-c505-45ef-98e5-aa524c4b05e7  What does hatching represent on the maps depic...
#
#                                                                        reference_answer  \
# id
# 450623f7-e644-4bfa-88d5-90f31dd15d99  Climate resilient development will not be poss...
# 79f98d3d-766b-4cbf-800f-03e87966e3e5  Coral reefs are projected to decline by a furt...
# 1ee224a2-62af-4877-b172-baec006512e6  The uncertainty in the total potential is typi...
# 16264bd2-510a-4368-a9d6-0a5fef7feb65  The proportion of emissions taken up by land a...
# c31c6857-c505-45ef-98e5-aa524c4b05e7  Hatching indicates areas where less than 70% o...
#
#                                                                       reference_context  \
# id
# 450623f7-e644-4bfa-88d5-90f31dd15d99  Document 196: Accelerated and equitable mitiga...
# 79f98d3d-766b-4cbf-800f-03e87966e3e5  Document 123: 71\nLong-Term Climate and Develo...
# 1ee224a2-62af-4877-b172-baec006512e6  Document 251: Where a gradual colour transitio...
# 16264bd2-510a-4368-a9d6-0a5fef7feb65  Document 166: While \nnatural land and ocean c...
# c31c6857-c505-45ef-98e5-aa524c4b05e7  Document 135: Interquartile ranges of WGLs by ...
#
#                                      conversation_history  \
# id
# 450623f7-e644-4bfa-88d5-90f31dd15d99                   []
# 79f98d3d-766b-4cbf-800f-03e87966e3e5                   []
# 1ee224a2-62af-4877-b172-baec006512e6                   []
# 16264bd2-510a-4368-a9d6-0a5fef7feb65                   []
# c31c6857-c505-45ef-98e5-aa524c4b05e7                   []
#
#                                                                                metadata
# id
# 450623f7-e644-4bfa-88d5-90f31dd15d99  {'question_type': 'simple', 'seed_document_id'...
# 79f98d3d-766b-4cbf-800f-03e87966e3e5  {'question_type': 'simple', 'seed_document_id'...
# 1ee224a2-62af-4877-b172-baec006512e6  {'question_type': 'simple', 'seed_document_id'...
# 16264bd2-510a-4368-a9d6-0a5fef7feb65  {'question_type': 'simple', 'seed_document_id'...
# c31c6857-c505-45ef-98e5-aa524c4b05e7  {'question_type': 'simple', 'seed_document_id'...

# %%
from giskard.rag import evaluate, RAGReport
from giskard.rag.metrics.ragas_metrics import ragas_context_recall, ragas_context_precision

# %%
def answer_fn(question, history=None):
    if history:
        answer = chat_engine.chat(question, chat_history=[ChatMessage(role=MessageRole.USER if msg["role"] =="user" else MessageRole.ASSISTANT,
                                                          content=msg["content"]) for msg in history])
    else:
        answer = chat_engine.chat(question, chat_history=[])
    return str(answer)

report = evaluate(answer_fn,
                testset=testset,
                knowledge_base=knowledge_base,
                metrics=[ragas_context_recall, ragas_context_precision])
# Out:
# Asking questions to the agent:   0%|          | 0/120 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 9
#       6         answer = chat_engine.chat(question, chat_history=[])
#       7     return str(answer)
# ----> 9 report = evaluate(answer_fn,
#      10                 testset=testset,
#      11                 knowledge_base=knowledge_base,
#      12                 metrics=[ragas_context_recall, ragas_context_precision])
#
# File ~/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/evaluate.py:79, in evaluate(answer_fn, testset, knowledge_base, llm_client, agent_description, metrics)
#      73 if testset is None:
#      74     testset = generate_testset(knowledge_base)
#      76 model_outputs = (
#      77     [_cast_to_agent_answer(ans) for ans in answer_fn]
#      78     if isinstance(answer_fn, Sequence)
# ---> 79     else _compute_answers(answer_fn, testset)
#      80 )
#      82 llm_client = llm_client or get_default_client()
#      84 # @TODO: improve this
#
# File ~/source/repos/BIMPoC/pythonenv/lib/python3.10/site-packages/giskard/rag/evaluate.py:141, in _compute_answers(answer_fn, testset)
#     138     if needs_history:
#     139         kwargs[ANSWER_FN_HISTORY_PARAM] = sample.conversation_history
# --> 141     answer = answer_fn(sample.question, **kwargs)
#     142     model_outputs.append(_cast_to_agent_answer(answer))
#     144 return model_outputs
#
# Cell In[57], line 6, in answer_fn(question, history)
#       3     answer = chat_engine.chat(question, chat_history=[ChatMessage(role=MessageRole.USER if msg["role"] =="user" else MessageRole.ASSISTANT,
#       4                                                       content=msg["content"]) for msg in history])
#       5 else:
# ----> 6     answer = chat_engine.chat(question, chat_history=[])
#       7 return str(answer)
#
# NameError: name 'chat_engine' is not defined
